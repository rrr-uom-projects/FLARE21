# %%
import numpy as np
import matplotlib.pyplot as plt
res = np.load("/data/FLARE21/results/roughSegmenter/results_grid.npy")
print(res.shape)
# Out:
# (1, 72, 5, 2)

# %%
for i in range(5):
    plt.hist(res[0,:,i,0])
print(np.nanmean(res[0,:,:,1], axis=0))
# Out:
# [0.97873158 0.97913465 0.97734042 0.99059186 0.90053329]
